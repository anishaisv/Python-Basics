# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df=pd.read_csv("Telco-Customer-Churn dataset.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4578  7766-CLTIC  Female              0      No         No      10
# 1277  4821-WQOYN  Female              0     Yes        Yes      72
# 956   3261-CQXOL  Female              0     Yes        Yes      71
# 4354  1955-IBMMB    Male              0      No         No      59
# 6115  3831-YCPUO  Female              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 4578          Yes            No             DSL                   No  ...
# 1277          Yes            No              No  No internet service  ...
# 956           Yes           Yes              No  No internet service  ...
# 4354          Yes            No              No  No internet service  ...
# 6115          Yes            No     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df.drop('customerID', axis='columns',inplace=True)       # customer id is useless. so drop it

# %%
df.dtypes     #customerid is dropped
 # noticed all datatypes.. MonthlyCharges is float64 but TotalCharges is object... wats going on there...
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values    #oops...they are string actually with single quotes
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df.MonthlyCharges.values
# Out:
# array([ 29.85,  56.95,  53.85, ...,  29.6 ,  74.4 , 105.65])

# %%
pd.to_numeric(df.TotalCharges)    # to convert strings to numbers... got error bz, some columns has space in this.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4288/842299256.py in <module>
# ----> 1 pd.to_numeric(df.TotalCharges)    # to convert strings to numbers
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull()         # this will ignore the errors which includes space.. isnull() will tel each value whether it is null or not
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
 df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]      # supply the whole thing into the dataframe, it will serve as the index...wherever the value is set to true( blank and null values)  it will show.
                  #look at the total charges ..it displayed the rows with null values
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
 df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()].shape   #shows the shape with null values for total charges
# Out:
# (11, 20)

# %%
df.shape        #ok so droping 11 rows from 7043 rows is not a big deal
# Out:
# (7043, 20)

# %%
df.iloc[488]    #iloc- integer location array index basically, if needed to know specific values of a particular row
# Out:
# gender                                 Female
# SeniorCitizen                               0
# Partner                                   Yes
# Dependents                                Yes
# tenure                                      0
# PhoneService                               No
# MultipleLines                No phone service
# InternetService                           DSL
# OnlineSecurity                            Yes
# OnlineBackup                               No
# DeviceProtection                          Yes
# TechSupport                               Yes
# StreamingTV                               Yes
# StreamingMovies                            No
# Contract                             Two year
# PaperlessBilling                          Yes
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges
# Churn                                      No
# Name: 488, dtype: object

# %%
df.iloc[488]['TotalCharges']     #to know the value of total charges specifically
# Out:
# ' '

# %%
df1=df[df.TotalCharges!=' ']   #dropping those null rows , if 'TotalChargesis not equal to space drop it..
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes    #ok 'TotalCharges is in object...
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
pd.to_numeric(df1.TotalCharges)     # ok now we will convert string TotalCharges into numbers
                                    #alright...its converted into numbers
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64

# %%
df1.TotalCharges=pd.to_numeric(df1.TotalCharges)   #store it into Totalcharges
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df1.TotalCharges.dtypes    #now its float
# Out:
# dtype('float64')

# %%
#tenure  shows loyal customers...want to check whether loyal customers are leaving or not...will draw a histogram

# %%
df1[df1.Churn=='No']     #this shows the not leaving customers with 'No'.. lets check thier tenure year
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# ...

# %%
df1[df1.Churn=='No'].tenure    #their (customers who are not leaving the company) tenure
# Out:
# 0        1
# 1       34
# 3       45
# 6       22
# 7       10
#         ..
# 7037    72
# 7038    24
# 7039    72
# 7040    11
# 7042    66
# Name: tenure, Length: 5163, dtype: int64

# %%
#plot a histogram
tenure_churn_no=df1[df1.Churn=='No'].tenure  #storing these details in a variable   
tenure_churn_yes=df1[df1.Churn=='Yes'].tenure

plt.hist([tenure_churn_no,tenure_churn_yes],color=['red','green'],label=['Churn=No','Churn=Yes'])
plt.legend()        # this is for representation of red and green in column

#from the output , more than 1000 customers with tenure more than 70 months are not leaving the company...

# %%
#same plot for monthly charges... customers may leave due to high monthly charges
